# %%
import random
from ketos.data_handling.database_interface import open_file, open_table, load_audio
# Out:
# 2022-01-15 18:47:12.618736: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-01-15 18:47:12.621746: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-01-15 18:47:12.621892: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (cdr1995.int.cedar.computecanada.ca): /proc/driver/nvidia/version does not exist
# 2022-01-15 18:47:12.624799: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/sadman/ketos_dl/lib/python3.7/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
db_save_path='../../saved_database/'
db_save_filename='test_ds_multiclass_original.h5'

# Open a connection to the database.
h5file = open_file(db_save_path+db_save_filename, 'r')
print(h5file)
# Out:
# ../../saved_database/test_ds_multiclass_original.h5 (File) ''
# Last modif.: 'Sat Jan 15 17:41:08 2022'
# Object Tree:
# / (RootGroup) ''
# /dolphin (Group) ''
# /dolphin/data (Table(1390,), fletcher32, shuffle, zlib(1)) ''
# /hb (Group) ''
# /hb/data (Table(24621,), fletcher32, shuffle, zlib(1)) ''
# /kw (Group) ''
# /kw/data (Table(49341,), fletcher32, shuffle, zlib(1)) ''
# /other (Group) ''
# /other/data (Table(41484,), fletcher32, shuffle, zlib(1)) ''

# %%
def plot_n_spectrogram(group, number_of_spec):
    """ Plots n number of spectrograms randomly selected from a hdf5 group
     
        Args:
            group: str
                hdf5 database's group name.
            number_of_spec: int
                Number of spectrograms to plot from each group
    """
    # Plots n number of spectrograms randomly selected from a hdf5 group
    table = open_table(h5file, group)
    print(table)
    specs_data = load_audio(table=table)
    print("Number of samples in ", group, ": ", len(specs_data))
    random_indices=random.sample(range(0,len(specs_data)), number_of_spec)
    for i in random_indices:
        specs_data[i].plot()

# %%
plot_n_spectrogram('/other/data', 3)
# Out:
# /other/data (Table(41484,), fletcher32, shuffle, zlib(1)) ''
# Number of samples in  /other/data :  41484
